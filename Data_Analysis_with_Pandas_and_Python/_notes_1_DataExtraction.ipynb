# %%
import pandas as pd

# %% [markdown]
# ## Other data extractions - .loc and .iloc methods

# %%
bond = pd.read_csv('db/jamesbond.csv')
bond
# Out:
#                                Film  Year           Actor            Director  \
# 0                            Dr. No  1962    Sean Connery       Terence Young
# 1             From Russia with Love  1963    Sean Connery       Terence Young
# 2                        Goldfinger  1964    Sean Connery        Guy Hamilton
# 3                       Thunderball  1965    Sean Connery       Terence Young
# 4                     Casino Royale  1967     David Niven          Ken Hughes
# 5               You Only Live Twice  1967    Sean Connery       Lewis Gilbert
# 6   On Her Majesty's Secret Service  1969  George Lazenby       Peter R. Hunt
# 7              Diamonds Are Forever  1971    Sean Connery        Guy Hamilton
# 8                  Live and Let Die  1973     Roger Moore        Guy Hamilton
# 9       The Man with the Golden Gun  1974     Roger Moore        Guy Hamilton
# 10             The Spy Who Loved Me  1977     Roger Moore       Lewis Gilbert
# 11                        Moonraker  1979     Roger Moore       Lewis Gilbert
# 12               For Your Eyes Only  1981     Roger Moore           John Glen
# 13            Never Say Never Again  1983    Sean Connery      Irvin Kershner
# 14                        Octopussy  1983     Roger Moore           John Glen
# 15                 A View to a Kill  1985     Roger Moore           John Glen
# 16             The Living Daylights  1987  Timothy Dalton           John Glen
# 17                  Licence to Kill  1989  Timothy Dalton           John Glen
# 18                        GoldenEye  1995  Pierce Brosnan     Martin Campbell
# 19              Tomorrow Never Dies  1997  Pierce Brosnan  Roger Spottiswoode
# 20          The World Is Not Enough  1999  Pierce Brosnan       Michael Apted
# 21                  Die Another Day  2002  Pierce Brosnan        Lee Tamahori
# 22                    Casino Royale  2006    Daniel Craig     Martin Campbell
# 23                Quantum of Solace  2008    Daniel Craig        Marc Forster
# 24                          Skyfall  2012    Daniel Craig          Sam Mendes
# 25                          Spectre  2015    Daniel Craig          Sam Mendes
#
#     Box Office  Budget  Bond Actor Salary
# 0        448.8     7.0                0.6
# 1        543.8    12.6                1.6
# 2        820.4    18.6                3.2
# 3        848.1    41.9                4.7
# 4        315.0    85.0                NaN
# 5        514.2    59.9                4.4
# 6        291.5    37.3                0.6
# 7        442.5    34.7                5.8
# 8        460.3    30.8                NaN
# 9        334.0    27.7                NaN
# 10       533.0    45.1                NaN
# 11       535.0    91.5                NaN
# 12       449.4    60.2                NaN
# 13       380.0    86.0                NaN
# 14       373.8    53.9                7.8
# 15       275.2    54.5                9.1
# 16       313.5    68.8                5.2
# 17       250.9    56.7                7.9
# 18       518.5    76.9                5.1
# 19       463.2   133.9               10.0
# 20       439.5   158.3               13.5
# 21       465.4   154.2               17.9
# 22       581.5   145.3                3.3
# 23       514.2   181.4                8.1
# 24       943.5   170.2               14.5
# 25       726.7   206.3                NaN

# %% [markdown]
# ### .set_index()

# %% [markdown]
# Setting the index after the data has been loaded
#
# Using any other data as index will allow it to have duplicates, do the indexes may not be unique

# %%
bond.set_index(keys='Film', # The new index
               inplace=True) #Setting to true will overwrite it to the dataframe

bond.head(3)
# Out:
#                        Year         Actor       Director  Box Office  Budget  \
# Film
# Dr. No                 1962  Sean Connery  Terence Young       448.8     7.0
# From Russia with Love  1963  Sean Connery  Terence Young       543.8    12.6
# Goldfinger             1964  Sean Connery   Guy Hamilton       820.4    18.6
#
#                        Bond Actor Salary
# Film
# Dr. No                               0.6
# From Russia with Love                1.6
# Goldfinger                           3.2

# %% [markdown]
# ### .reset_index()

# %% [markdown]
# Resetting the original indexes

# %%
bond.reset_index(inplace=True, drop=False) #the 'drop' parameter lets you decide if the current index should be dropped, 'False' is the default

bond.head(3)
# Out:
#                     Film  Year         Actor       Director  Box Office  \
# 0                 Dr. No  1962  Sean Connery  Terence Young       448.8
# 1  From Russia with Love  1963  Sean Connery  Terence Young       543.8
# 2             Goldfinger  1964  Sean Connery   Guy Hamilton       820.4
#
#    Budget  Bond Actor Salary
# 0     7.0                0.6
# 1    12.6                1.6
# 2    18.6                3.2

# %% [markdown]
# ### .loc[ ] -> Retrieving rows by index label
#
# Supports slicing opperations just as a python list would

# %%
bond.set_index(keys='Film', inplace=True)
bond.sort_index(inplace=True) # it is recommended to sort the values before retrieving any rows since there is an improvement in the time spent when looking through ordered data
bond.head(3)
# Out:
#                   Year         Actor         Director  Box Office  Budget  \
# Film
# A View to a Kill  1985   Roger Moore        John Glen       275.2    54.5
# Casino Royale     2006  Daniel Craig  Martin Campbell       581.5   145.3
# Casino Royale     1967   David Niven       Ken Hughes       315.0    85.0
#
#                   Bond Actor Salary
# Film
# A View to a Kill                9.1
# Casino Royale                   3.3
# Casino Royale                   NaN

# %% [markdown]
#     If there is only one correspondance, it will return a Series with the corresponding information for that row

# %%
bond.loc['Goldfinger']
# Out:
# Year                         1964
# Actor                Sean Connery
# Director             Guy Hamilton
# Box Office                  820.4
# Budget                       18.6
# Bond Actor Salary             3.2
# Name: Goldfinger, dtype: object

# %% [markdown]
#     If there is more than one correspondance, it will return a data frame

# %%
bond.loc['Casino Royale']
# Out:
#                Year         Actor         Director  Box Office  Budget  \
# Film
# Casino Royale  2006  Daniel Craig  Martin Campbell       581.5   145.3
# Casino Royale  1967   David Niven       Ken Hughes       315.0    85.0
#
#                Bond Actor Salary
# Film
# Casino Royale                3.3
# Casino Royale                NaN

# %%
bond.loc[['Live and Let Die','Die Another Day']] #multiple selections are made within brackets
# Out:
#                   Year           Actor      Director  Box Office  Budget  \
# Film
# Live and Let Die  1973     Roger Moore  Guy Hamilton       460.3    30.8
# Die Another Day   2002  Pierce Brosnan  Lee Tamahori       465.4   154.2
#
#                   Bond Actor Salary
# Film
# Live and Let Die                NaN
# Die Another Day                17.9

# %% [markdown]
#     Creating a sliced selection
#
# The difference between .loc[] and slicing a list is that the upper range is inclusive, whereas on the list it is exclusive (is not included on the extracted data)

# %%
bond.loc['Diamonds Are Forever':'Licence to Kill']
# Out:
#                        Year           Actor         Director  Box Office  \
# Film
# Diamonds Are Forever   1971    Sean Connery     Guy Hamilton       442.5
# Die Another Day        2002  Pierce Brosnan     Lee Tamahori       465.4
# Dr. No                 1962    Sean Connery    Terence Young       448.8
# For Your Eyes Only     1981     Roger Moore        John Glen       449.4
# From Russia with Love  1963    Sean Connery    Terence Young       543.8
# GoldenEye              1995  Pierce Brosnan  Martin Campbell       518.5
# Goldfinger             1964    Sean Connery     Guy Hamilton       820.4
# Licence to Kill        1989  Timothy Dalton        John Glen       250.9
#
#                        Budget  Bond Actor Salary
# Film
# Diamonds Are Forever     34.7                5.8
# Die Another Day         154.2               17.9
# Dr. No                    7.0                0.6
# For Your Eyes Only       60.2                NaN
# From Russia with Love    12.6                1.6
# GoldenEye                76.9                5.1
# Goldfinger               18.6                3.2
# Licence to Kill          56.7                7.9

# %% [markdown]
# ### Second arguments

# %%
bond.loc['Moonraker','Actor'] # looking for index 'Moonraker' on column 'Actor'
# Out:
# 'Roger Moore'

# %%
bond.loc['Octopussy', ['Actor','Director']]
# Out:
# Actor       Roger Moore
# Director      John Glen
# Name: Octopussy, dtype: object

# %%
bond.loc[['Octopussy',"GoldenEye"], ['Actor','Director']]
# Out:
#                     Actor         Director
# Film
# Octopussy     Roger Moore        John Glen
# GoldenEye  Pierce Brosnan  Martin Campbell

# %%
bond.loc[['Octopussy',"GoldenEye"], 'Year':'Director'] # intervals may also be used on the arguments
# Out:
#            Year           Actor         Director
# Film
# Octopussy  1983     Roger Moore        John Glen
# GoldenEye  1995  Pierce Brosnan  Martin Campbell

# %% [markdown]
# ### .iloc[ ] -> Retrieving rows by index position
#
# The upper range is exclusive

# %% [markdown]
#     The iloc works for both numeric or labeled indexes

# %%
bond.iloc[:5]
# Out:
#                       Year           Actor         Director  Box Office  \
# Film
# A View to a Kill      1985     Roger Moore        John Glen       275.2
# Casino Royale         2006    Daniel Craig  Martin Campbell       581.5
# Casino Royale         1967     David Niven       Ken Hughes       315.0
# Diamonds Are Forever  1971    Sean Connery     Guy Hamilton       442.5
# Die Another Day       2002  Pierce Brosnan     Lee Tamahori       465.4
#
#                       Budget  Bond Actor Salary
# Film
# A View to a Kill        54.5                9.1
# Casino Royale          145.3                3.3
# Casino Royale           85.0                NaN
# Diamonds Are Forever    34.7                5.8
# Die Another Day        154.2               17.9

# %%
bond.reset_index(inplace=True)

# %%
bond.iloc[:5] #does not include position 5
# Out:
#                    Film  Year           Actor         Director  Box Office  \
# 0      A View to a Kill  1985     Roger Moore        John Glen       275.2
# 1         Casino Royale  2006    Daniel Craig  Martin Campbell       581.5
# 2         Casino Royale  1967     David Niven       Ken Hughes       315.0
# 3  Diamonds Are Forever  1971    Sean Connery     Guy Hamilton       442.5
# 4       Die Another Day  2002  Pierce Brosnan     Lee Tamahori       465.4
#
#    Budget  Bond Actor Salary
# 0    54.5                9.1
# 1   145.3                3.3
# 2    85.0                NaN
# 3    34.7                5.8
# 4   154.2               17.9

# %%
bond.iloc[[2,4]]
# Out:
#               Film  Year           Actor      Director  Box Office  Budget  \
# 2    Casino Royale  1967     David Niven    Ken Hughes       315.0    85.0
# 4  Die Another Day  2002  Pierce Brosnan  Lee Tamahori       465.4   154.2
#
#    Bond Actor Salary
# 2                NaN
# 4               17.9

# %% [markdown]
# ### Second arguments

# %%
bond.iloc[11,2] # 11th row, 2nd column
# Out:
# 'Roger Moore'

# %%
bond.iloc[[11,15],[1,3]]
# Out:
#     Year       Director
# 11  1973   Guy Hamilton
# 15  1969  Peter R. Hunt

# %%
bond.iloc[[11,15],1:4] # remembering that the upper range is exclusive
# Out:
#     Year           Actor       Director
# 11  1973     Roger Moore   Guy Hamilton
# 15  1969  George Lazenby  Peter R. Hunt

# %% [markdown]
# ### Setting new values for a specific cell

# %%
bond.iloc[11,2] = 'EXAMPLE'

bond.iloc[11]
# Out:
# Film                 Live and Let Die
# Year                             1973
# Actor                         EXAMPLE
# Director                 Guy Hamilton
# Box Office                      460.3
# Budget                           30.8
# Bond Actor Salary                 NaN
# Name: 11, dtype: object

# %% [markdown]
#     Also works with .loc[] and for setting multiple values

# %%
bond.set_index(keys='Film', inplace=True)

bond.loc['Moonraker', ['Actor','Director','Box Office']] = ['Example1','Example2','0']
bond.loc['Moonraker']
# Out:
# Year                     1979
# Actor                Example1
# Director             Example2
# Box Office                  0
# Budget                   91.5
# Bond Actor Salary         NaN
# Name: Moonraker, dtype: object

# %% [markdown]
# ### Setting multiple values in the DataFrame

# %% [markdown]
#     loc and iloc can also receive boolean or mathematical comparisons

# %%
#bond.loc[bond['Actor']=='Sean Connery'] = 'Sir Sean Connery' # this way it would fill the whole line and not only the 'Actor' column

bond.loc[bond['Actor']=='Sean Connery','Actor'] = 'Sir Sean Connery' # this way, it will fill only the 'Actor' column

bond
# Out:
#                                  Year             Actor            Director  \
# Film
# A View to a Kill                 1985       Roger Moore           John Glen
# Casino Royale                    2006      Daniel Craig     Martin Campbell
# Casino Royale                    1967       David Niven          Ken Hughes
# Diamonds Are Forever             1971  Sir Sean Connery        Guy Hamilton
# Die Another Day                  2002    Pierce Brosnan        Lee Tamahori
# Dr. No                           1962  Sir Sean Connery       Terence Young
# For Your Eyes Only               1981       Roger Moore           John Glen
# From Russia with Love            1963  Sir Sean Connery       Terence Young
# GoldenEye                        1995    Pierce Brosnan     Martin Campbell
# Goldfinger                       1964  Sir Sean Connery        Guy Hamilton
# Licence to Kill                  1989    Timothy Dalton           John Glen
# Live and Let Die                 1973           EXAMPLE        Guy Hamilton
# Moonraker                        1979          Example1            Example2
# Never Say Never Again            1983  Sir Sean Connery      Irvin Kershner
# Octopussy                        1983       Roger Moore           John Glen
# On Her Majesty's Secret Service  1969    George Lazenby       Peter R. Hunt
# Quantum of Solace                2008      Daniel Craig        Marc Forster
# Skyfall                          2012      Daniel Craig          Sam Mendes
# Spectre                          2015      Daniel Craig          Sam Mendes
# The Living Daylights             1987    Timothy Dalton           John Glen
# The Man with the Golden Gun      1974       Roger Moore        Guy Hamilton
# The Spy Who Loved Me             1977       Roger Moore       Lewis Gilbert
# The World Is Not Enough          1999    Pierce Brosnan       Michael Apted
# Thunderball                      1965  Sir Sean Connery       Terence Young
# Tomorrow Never Dies              1997    Pierce Brosnan  Roger Spottiswoode
# You Only Live Twice              1967  Sir Sean Connery       Lewis Gilbert
#
#                                 Box Office  Budget  Bond Actor Salary
# Film
# A View to a Kill                     275.2    54.5                9.1
# Casino Royale                        581.5   145.3                3.3
# Casino Royale                        315.0    85.0                NaN
# Diamonds Are Forever                 442.5    34.7                5.8
# Die Another Day                      465.4   154.2               17.9
# Dr. No                               448.8     7.0                0.6
# For Your Eyes Only                   449.4    60.2                NaN
# From Russia with Love                543.8    12.6                1.6
# GoldenEye                            518.5    76.9                5.1
# Goldfinger                           820.4    18.6                3.2
# Licence to Kill                      250.9    56.7                7.9
# Live and Let Die                     460.3    30.8                NaN
# Moonraker                                0    91.5                NaN
# Never Say Never Again                380.0    86.0                NaN
# Octopussy                            373.8    53.9                7.8
# On Her Majesty's Secret Service      291.5    37.3                0.6
# Quantum of Solace                    514.2   181.4                8.1
# Skyfall                              943.5   170.2               14.5
# Spectre                              726.7   206.3                NaN
# The Living Daylights                 313.5    68.8                5.2
# The Man with the Golden Gun          334.0    27.7                NaN
# The Spy Who Loved Me                 533.0    45.1                NaN
# The World Is Not Enough              439.5   158.3               13.5
# Thunderball                          848.1    41.9                4.7
# Tomorrow Never Dies                  463.2   133.9               10.0
# You Only Live Twice                  514.2    59.9                4.4

# %% [markdown]
# ### Renaming index labels or columns .rename()

# %% [markdown]
#     Renaming index labels

# %% [markdown]
# Using the mapper argument

# %%
bond.rename(mapper={'GoldenEye':'Golden Eye','Goldfinger':'Gold Finger'}, # acceps dictionaries | by default it looks to the '0' axis (row axis)
            inplace=True) # setting to true to change the df
bond.head(10)
# Out:
#                        Year             Actor         Director Box Office  \
# Film
# A View to a Kill       1985       Roger Moore        John Glen      275.2
# Casino Royale          2006      Daniel Craig  Martin Campbell      581.5
# Casino Royale          1967       David Niven       Ken Hughes      315.0
# Diamonds Are Forever   1971  Sir Sean Connery     Guy Hamilton      442.5
# Die Another Day        2002    Pierce Brosnan     Lee Tamahori      465.4
# Dr. No                 1962  Sir Sean Connery    Terence Young      448.8
# For Your Eyes Only     1981       Roger Moore        John Glen      449.4
# From Russia with Love  1963  Sir Sean Connery    Terence Young      543.8
# Golden Eye             1995    Pierce Brosnan  Martin Campbell      518.5
# Gold Finger            1964  Sir Sean Connery     Guy Hamilton      820.4
#
#                        Budget  Bond Actor Salary
# Film
# A View to a Kill         54.5                9.1
# Casino Royale           145.3                3.3
# Casino Royale            85.0                NaN
# Diamonds Are Forever     34.7                5.8
# Die Another Day         154.2               17.9
# Dr. No                    7.0                0.6
# For Your Eyes Only       60.2                NaN
# From Russia with Love    12.6                1.6
# Golden Eye               76.9                5.1
# Gold Finger              18.6                3.2

# %% [markdown]
# Using index argument

# %%
bond.rename(index={'Dr. No':'Doctor No'}, # also acceps dictionaries
            inplace=True) # setting to true to change the df
bond.head(10)
# Out:
#                        Year             Actor         Director Box Office  \
# Film
# A View to a Kill       1985       Roger Moore        John Glen      275.2
# Casino Royale          2006      Daniel Craig  Martin Campbell      581.5
# Casino Royale          1967       David Niven       Ken Hughes      315.0
# Diamonds Are Forever   1971  Sir Sean Connery     Guy Hamilton      442.5
# Die Another Day        2002    Pierce Brosnan     Lee Tamahori      465.4
# Doctor No              1962  Sir Sean Connery    Terence Young      448.8
# For Your Eyes Only     1981       Roger Moore        John Glen      449.4
# From Russia with Love  1963  Sir Sean Connery    Terence Young      543.8
# Golden Eye             1995    Pierce Brosnan  Martin Campbell      518.5
# Gold Finger            1964  Sir Sean Connery     Guy Hamilton      820.4
#
#                        Budget  Bond Actor Salary
# Film
# A View to a Kill         54.5                9.1
# Casino Royale           145.3                3.3
# Casino Royale            85.0                NaN
# Diamonds Are Forever     34.7                5.8
# Die Another Day         154.2               17.9
# Doctor No                 7.0                0.6
# For Your Eyes Only       60.2                NaN
# From Russia with Love    12.6                1.6
# Golden Eye               76.9                5.1
# Gold Finger              18.6                3.2

# %% [markdown]
#     Renaming column Labels

# %% [markdown]
# Using the mapper argument

# %%
bond.rename(mapper={'Box Office':'Revenue'}, axis=1, # axis=1 indicates we're looking for these values on the columns
            inplace=True)

#OR

bond.rename(mapper={'Box Office':'Revenue'}, axis='columns', # axis='columns' indicates we're looking for these values on the columns, works the same as axis=1
            inplace=True)   

bond.head(3)
# Out:
#                   Year         Actor         Director Revenue  Budget  \
# Film
# A View to a Kill  1985   Roger Moore        John Glen   275.2    54.5
# Casino Royale     2006  Daniel Craig  Martin Campbell   581.5   145.3
# Casino Royale     1967   David Niven       Ken Hughes   315.0    85.0
#
#                   Bond Actor Salary
# Film
# A View to a Kill                9.1
# Casino Royale                   3.3
# Casino Royale                   NaN

# %% [markdown]
# Using the columns argument directly

# %%
bond.rename(columns={'Bond Actor Salary':'Actor Salary'},# no need to set the axis argument
            inplace=True)  

bond.head(3)
# Out:
#                   Year         Actor         Director Revenue  Budget  \
# Film
# A View to a Kill  1985   Roger Moore        John Glen   275.2    54.5
# Casino Royale     2006  Daniel Craig  Martin Campbell   581.5   145.3
# Casino Royale     1967   David Niven       Ken Hughes   315.0    85.0
#
#                   Actor Salary
# Film
# A View to a Kill           9.1
# Casino Royale              3.3
# Casino Royale              NaN

# %% [markdown]
# Overwriting the columns directly

# %%
bond.columns
# Out:
# Index(['Year', 'Actor', 'Director', 'Revenue', 'Budget', 'Actor Salary'], dtype='object')

# %%
bond.columns=['Year', 'Actor', 'Director', 'Box Office', 'Budget', 'Bond Salary']

bond.head(5)
# Out:
#                       Year             Actor         Director Box Office  \
# Film
# A View to a Kill      1985       Roger Moore        John Glen      275.2
# Casino Royale         2006      Daniel Craig  Martin Campbell      581.5
# Casino Royale         1967       David Niven       Ken Hughes      315.0
# Diamonds Are Forever  1971  Sir Sean Connery     Guy Hamilton      442.5
# Die Another Day       2002    Pierce Brosnan     Lee Tamahori      465.4
#
#                       Budget  Bond Salary
# Film
# A View to a Kill        54.5          9.1
# Casino Royale          145.3          3.3
# Casino Royale           85.0          NaN
# Diamonds Are Forever    34.7          5.8
# Die Another Day        154.2         17.9

# %% [markdown]
# Overwriting based on a condition

# %%
bond.columns=[column_name.replace(" ","_") for column_name in bond.columns]

bond.columns
# Out:
# Index(['Year', 'Actor', 'Director', 'Box_Office', 'Budget', 'Bond_Salary'], dtype='object')

# %% [markdown]
# ### Deleting rows or Columns

# %% [markdown]
# .drop() method

# %% [markdown]
#     Lines

# %%
bond.drop('A View to a Kill', inplace=True)

#if 2 or more indexes have the same label name, all will be removed
bond.drop(['Casino Royale','Diamonds Are Forever'], inplace=True) # for multiple lines, just add a list

bond.head(3)
# Out:
#                     Year             Actor       Director Box_Office  Budget  \
# Film
# Die Another Day     2002    Pierce Brosnan   Lee Tamahori      465.4   154.2
# Doctor No           1962  Sir Sean Connery  Terence Young      448.8     7.0
# For Your Eyes Only  1981       Roger Moore      John Glen      449.4    60.2
#
#                     Bond_Salary
# Film
# Die Another Day            17.9
# Doctor No                   0.6
# For Your Eyes Only          NaN

# %% [markdown]
#     Columns

# %%
bond.drop('Bond_Salary', axis=1) # for columns the axis must be specified
# Out:
#                                  Year             Actor            Director  \
# Film
# Die Another Day                  2002    Pierce Brosnan        Lee Tamahori
# Doctor No                        1962  Sir Sean Connery       Terence Young
# For Your Eyes Only               1981       Roger Moore           John Glen
# From Russia with Love            1963  Sir Sean Connery       Terence Young
# Golden Eye                       1995    Pierce Brosnan     Martin Campbell
# Gold Finger                      1964  Sir Sean Connery        Guy Hamilton
# Licence to Kill                  1989    Timothy Dalton           John Glen
# Live and Let Die                 1973           EXAMPLE        Guy Hamilton
# Moonraker                        1979          Example1            Example2
# Never Say Never Again            1983  Sir Sean Connery      Irvin Kershner
# Octopussy                        1983       Roger Moore           John Glen
# On Her Majesty's Secret Service  1969    George Lazenby       Peter R. Hunt
# Quantum of Solace                2008      Daniel Craig        Marc Forster
# Skyfall                          2012      Daniel Craig          Sam Mendes
# Spectre                          2015      Daniel Craig          Sam Mendes
# The Living Daylights             1987    Timothy Dalton           John Glen
# The Man with the Golden Gun      1974       Roger Moore        Guy Hamilton
# The Spy Who Loved Me             1977       Roger Moore       Lewis Gilbert
# The World Is Not Enough          1999    Pierce Brosnan       Michael Apted
# Thunderball                      1965  Sir Sean Connery       Terence Young
# Tomorrow Never Dies              1997    Pierce Brosnan  Roger Spottiswoode
# You Only Live Twice              1967  Sir Sean Connery       Lewis Gilbert
#
#                                 Box_Office  Budget
# Film
# Die Another Day                      465.4   154.2
# Doctor No                            448.8     7.0
# For Your Eyes Only                   449.4    60.2
# From Russia with Love                543.8    12.6
# Golden Eye                           518.5    76.9
# Gold Finger                          820.4    18.6
# Licence to Kill                      250.9    56.7
# Live and Let Die                     460.3    30.8
# Moonraker                                0    91.5
# Never Say Never Again                380.0    86.0
# Octopussy                            373.8    53.9
# On Her Majesty's Secret Service      291.5    37.3
# Quantum of Solace                    514.2   181.4
# Skyfall                              943.5   170.2
# Spectre                              726.7   206.3
# The Living Daylights                 313.5    68.8
# The Man with the Golden Gun          334.0    27.7
# The Spy Who Loved Me                 533.0    45.1
# The World Is Not Enough              439.5   158.3
# Thunderball                          848.1    41.9
# Tomorrow Never Dies                  463.2   133.9
# You Only Live Twice                  514.2    59.9

# %% [markdown]
# .pop( method) -> permanet operation

# %% [markdown]
#     as it is permanet and returns the Series, we can store it on a variable

# %%
bond.pop('Budget') 

#budget = bond.pop('Budget')
# Out:
# Film
# Die Another Day                    154.2
# Doctor No                            7.0
# For Your Eyes Only                  60.2
# From Russia with Love               12.6
# Golden Eye                          76.9
# Gold Finger                         18.6
# Licence to Kill                     56.7
# Live and Let Die                    30.8
# Moonraker                           91.5
# Never Say Never Again               86.0
# Octopussy                           53.9
# On Her Majesty's Secret Service     37.3
# Quantum of Solace                  181.4
# Skyfall                            170.2
# Spectre                            206.3
# The Living Daylights                68.8
# The Man with the Golden Gun         27.7
# The Spy Who Loved Me                45.1
# The World Is Not Enough            158.3
# Thunderball                         41.9
# Tomorrow Never Dies                133.9
# You Only Live Twice                 59.9
# Name: Budget, dtype: float64

# %% [markdown]
# del keyword -> also a permanen operation

# %%
del bond['Director']

bond.head(3)
# Out:
#                     Year             Actor Box_Office  Bond_Salary
# Film
# Die Another Day     2002    Pierce Brosnan      465.4         17.9
# Doctor No           1962  Sir Sean Connery      448.8          0.6
# For Your Eyes Only  1981       Roger Moore      449.4          NaN

# %% [markdown]
# ### Creating Random samples

# %%
bond.sample() # it will extract a single random row by default
# Out:
#                     Year        Actor Box_Office  Bond_Salary
# Film
# For Your Eyes Only  1981  Roger Moore      449.4          NaN

# %%
bond.sample(axis=1) # or axis='column' will extract a random column
# Out:
#                                 Box_Office
# Film
# Die Another Day                      465.4
# Doctor No                            448.8
# For Your Eyes Only                   449.4
# From Russia with Love                543.8
# Golden Eye                           518.5
# Gold Finger                          820.4
# Licence to Kill                      250.9
# Live and Let Die                     460.3
# Moonraker                                0
# Never Say Never Again                380.0
# Octopussy                            373.8
# On Her Majesty's Secret Service      291.5
# Quantum of Solace                    514.2
# Skyfall                              943.5
# Spectre                              726.7
# The Living Daylights                 313.5
# The Man with the Golden Gun          334.0
# The Spy Who Loved Me                 533.0
# The World Is Not Enough              439.5
# Thunderball                          848.1
# Tomorrow Never Dies                  463.2
# You Only Live Twice                  514.2

# %%
bond.sample(n=5) # n = number of rows, the order is also random
# Out:
#                       Year             Actor Box_Office  Bond_Salary
# Film
# Tomorrow Never Dies   1997    Pierce Brosnan      463.2         10.0
# Golden Eye            1995    Pierce Brosnan      518.5          5.1
# Octopussy             1983       Roger Moore      373.8          7.8
# The Living Daylights  1987    Timothy Dalton      313.5          5.2
# Doctor No             1962  Sir Sean Connery      448.8          0.6

# %%
bond.sample(frac=.25) # we may provide a fraction/percentage instead of the number of samples
# Out:
#                        Year             Actor Box_Office  Bond_Salary
# Film
# You Only Live Twice    1967  Sir Sean Connery      514.2          4.4
# Never Say Never Again  1983  Sir Sean Connery      380.0          NaN
# Golden Eye             1995    Pierce Brosnan      518.5          5.1
# The Spy Who Loved Me   1977       Roger Moore      533.0          NaN
# Moonraker              1979          Example1          0          NaN
# Licence to Kill        1989    Timothy Dalton      250.9          7.9

# %% [markdown]
# ### .nsmallest() and .nlargest() methods

# %%
bond.nlargest(3, columns='Bond_Salary') #first argument is the rows number 'n=' we can used the declared argument or just the positional argument
# returns a dataframe
# Out:
#                          Year           Actor Box_Office  Bond_Salary
# Film
# Die Another Day          2002  Pierce Brosnan      465.4         17.9
# Skyfall                  2012    Daniel Craig      943.5         14.5
# The World Is Not Enough  1999  Pierce Brosnan      439.5         13.5

# %%
bond['Bond_Salary'].nlargest(3) # returns a series
# Out:
# Film
# Die Another Day            17.9
# Skyfall                    14.5
# The World Is Not Enough    13.5
# Name: Bond_Salary, dtype: float64

# %%
bond.nsmallest(n=2, columns='Bond Salary') # returns a dataframe
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\pandas\core\indexes\base.py:3803, in Index.get_loc(self, key, method, tolerance)
#    3802 try:
# -> 3803     return self._engine.get_loc(casted_key)
#    3804 except KeyError as err:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Bond Salary'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# d:\Gi\Documents\Udemy\Data_Analysis_with_Pandas_and_Python\_notes_1_DataExtraction.ipynb Cell 76 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/d%3A/Gi/Documents/Udemy/Data_Analysis_with_Pandas_and_Python/_notes_1_DataExtraction.ipynb#Y133sZmlsZQ%3D%3D?line=0'>1</a> bond.nsmallest(n=2, columns='Bond Salary')
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\pandas\core\frame.py:7425, in DataFrame.nsmallest(self, n, columns, keep)
#    7329 def nsmallest(self, n: int, columns: IndexLabel, keep: str = "first") -> DataFrame:
#    7330     """
#    7331     Return the first `n` rows ordered by `columns` in ascending order.
#    7332
#    (...)
#    7423     Nauru         337000  182      NR
#    7424     """
# -> 7425     return algorithms.SelectNFrame(
#    7426         self, n=n, keep=keep, columns=columns
#    7427     ).nsmallest()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\pandas\core\algorithms.py:1277, in SelectN.nsmallest(self)
#    1275 @final
#    1276 def nsmallest(self):
# -> 1277     return self.compute("nsmallest")
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\pandas\core\algorithms.py:1402, in SelectNFrame.compute(self, method)
#    1399 columns = self.columns
#    1401 for column in columns:
# -> 1402     dtype = frame[column].dtype
#    1403     if not self.is_valid_dtype_n_method(dtype):
#    1404         raise TypeError(
#    1405             f"Column {repr(column)} has dtype {dtype}, "
#    1406             f"cannot use method {repr(method)} with this dtype"
#    1407         )
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\pandas\core\frame.py:3804, in DataFrame.__getitem__(self, key)
#    3802 if self.columns.nlevels > 1:
#    3803     return self._getitem_multilevel(key)
# -> 3804 indexer = self.columns.get_loc(key)
#    3805 if is_integer(indexer):
#    3806     indexer = [indexer]
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key, method, tolerance)
#    3803     return self._engine.get_loc(casted_key)
#    3804 except KeyError as err:
# -> 3805     raise KeyError(key) from err
#    3806 except TypeError:
#    3807     # If we have a listlike key, _check_indexing_error will raise
#    3808     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3809     #  the TypeError.
#    3810     self._check_indexing_error(key)
#
# KeyError: 'Bond Salary'

# %%
bond['Bond Salary'].nsmallest(2) # returns a series
# Out:
# Film
# Doctor No                          0.6
# On Her Majesty's Secret Service    0.6
# Name: Bond Salary, dtype: float64

# %% [markdown]
# ### Filtering with the .where() method
#
# Accepts boolean expressions

# %%
bond.where(bond['Year']>1980)
# Out:
#                                    Year             Actor Revenue  Bond Salary
# Film
# Die Another Day                  2002.0    Pierce Brosnan   465.4         17.9
# Doctor No                           NaN               NaN     NaN          NaN
# For Your Eyes Only               1981.0       Roger Moore   449.4          NaN
# From Russia with Love               NaN               NaN     NaN          NaN
# Golden Eye                       1995.0    Pierce Brosnan   518.5          5.1
# Gold Finger                         NaN               NaN     NaN          NaN
# Licence to Kill                  1989.0    Timothy Dalton   250.9          7.9
# Live and Let Die                    NaN               NaN     NaN          NaN
# Moonraker                           NaN               NaN     NaN          NaN
# Never Say Never Again            1983.0  Sir Sean Connery   380.0          NaN
# Octopussy                        1983.0       Roger Moore   373.8          7.8
# On Her Majesty's Secret Service     NaN               NaN     NaN          NaN
# Quantum of Solace                2008.0      Daniel Craig   514.2          8.1
# Skyfall                          2012.0      Daniel Craig   943.5         14.5
# Spectre                          2015.0      Daniel Craig   726.7          NaN
# The Living Daylights             1987.0    Timothy Dalton   313.5          5.2
# The Man with the Golden Gun         NaN               NaN     NaN          NaN
# The Spy Who Loved Me                NaN               NaN     NaN          NaN
# The World Is Not Enough          1999.0    Pierce Brosnan   439.5         13.5
# Thunderball                         NaN               NaN     NaN          NaN
# Tomorrow Never Dies              1997.0    Pierce Brosnan   463.2         10.0
# You Only Live Twice                 NaN               NaN     NaN          NaN

# %% [markdown]
#     Multiple arguments

# %%
mask1 = bond['Year'] >2010
mask2 = bond['Actor'] == 'Daniel Craig'

bond.where(mask1 & mask2)
# Out:
#                                    Year         Actor Box_Office  Bond_Salary
# Film
# Die Another Day                     NaN           NaN        NaN          NaN
# Doctor No                           NaN           NaN        NaN          NaN
# For Your Eyes Only                  NaN           NaN        NaN          NaN
# From Russia with Love               NaN           NaN        NaN          NaN
# Golden Eye                          NaN           NaN        NaN          NaN
# Gold Finger                         NaN           NaN        NaN          NaN
# Licence to Kill                     NaN           NaN        NaN          NaN
# Live and Let Die                    NaN           NaN        NaN          NaN
# Moonraker                           NaN           NaN        NaN          NaN
# Never Say Never Again               NaN           NaN        NaN          NaN
# Octopussy                           NaN           NaN        NaN          NaN
# On Her Majesty's Secret Service     NaN           NaN        NaN          NaN
# Quantum of Solace                   NaN           NaN        NaN          NaN
# Skyfall                          2012.0  Daniel Craig      943.5         14.5
# Spectre                          2015.0  Daniel Craig      726.7          NaN
# The Living Daylights                NaN           NaN        NaN          NaN
# The Man with the Golden Gun         NaN           NaN        NaN          NaN
# The Spy Who Loved Me                NaN           NaN        NaN          NaN
# The World Is Not Enough             NaN           NaN        NaN          NaN
# Thunderball                         NaN           NaN        NaN          NaN
# Tomorrow Never Dies                 NaN           NaN        NaN          NaN
# You Only Live Twice                 NaN           NaN        NaN          NaN

# %% [markdown]
# ### .query() method
#
# Accepts boolean expressions inside a string

# %%
bond.query('Actor == "Daniel Craig"') # it is necessary to use a combination of double and single quotes, the order does not matter
# Out:
#                    Year         Actor Box_Office  Bond_Salary
# Film
# Quantum of Solace  2008  Daniel Craig      514.2          8.1
# Skyfall            2012  Daniel Craig      943.5         14.5
# Spectre            2015  Daniel Craig      726.7          NaN

# %%
bond.query('Actor == "Daniel Craig" and Year > 2010')
# Out:
#          Year         Actor Box_Office  Bond_Salary
# Film
# Skyfall  2012  Daniel Craig      943.5         14.5
# Spectre  2015  Daniel Craig      726.7          NaN

# %%
bond.query("Actor in ['Roger Moore', 'Timothy Dalton']")
# Out:
#                              Year           Actor Box_Office  Bond_Salary
# Film
# For Your Eyes Only           1981     Roger Moore      449.4          NaN
# Licence to Kill              1989  Timothy Dalton      250.9          7.9
# Octopussy                    1983     Roger Moore      373.8          7.8
# The Living Daylights         1987  Timothy Dalton      313.5          5.2
# The Man with the Golden Gun  1974     Roger Moore      334.0          NaN
# The Spy Who Loved Me         1977     Roger Moore      533.0          NaN

# %%
bond.query("Actor not in ['Roger Moore', 'Timothy Dalton','Sir Sean Connery']")
# Out:
#                                  Year           Actor Box_Office  Bond_Salary
# Film
# Die Another Day                  2002  Pierce Brosnan      465.4         17.9
# Golden Eye                       1995  Pierce Brosnan      518.5          5.1
# Live and Let Die                 1973         EXAMPLE      460.3          NaN
# Moonraker                        1979        Example1          0          NaN
# On Her Majesty's Secret Service  1969  George Lazenby      291.5          0.6
# Quantum of Solace                2008    Daniel Craig      514.2          8.1
# Skyfall                          2012    Daniel Craig      943.5         14.5
# Spectre                          2015    Daniel Craig      726.7          NaN
# The World Is Not Enough          1999  Pierce Brosnan      439.5         13.5
# Tomorrow Never Dies              1997  Pierce Brosnan      463.2         10.0

# %% [markdown]
# ### .apply() method
#
# applies a function to a series or dataframe

# %%
def convert_values(number):
    return str(number)+" Millions"

columns = ['Box_Office', 'Bond_Salary']

for col in columns:
    bond[col] = bond[col].apply(convert_values)

bond.head(5)
# Out:
#                        Year             Actor      Box_Office    Bond_Salary
# Film
# Die Another Day        2002    Pierce Brosnan  465.4 Millions  17.9 Millions
# Doctor No              1962  Sir Sean Connery  448.8 Millions   0.6 Millions
# For Your Eyes Only     1981       Roger Moore  449.4 Millions   nan Millions
# From Russia with Love  1963  Sir Sean Connery  543.8 Millions   1.6 Millions
# Golden Eye             1995    Pierce Brosnan  518.5 Millions   5.1 Millions

# %%
def ranking (row):
    revenue=row[2]

    if int(revenue) > 500:
        return 'Expensive'
    else:
        return 'Cheap'

bond.apply(ranking, axis='columns') # for every row we will travell through all columns
# Out:
# Film
# Die Another Day                        Cheap
# Doctor No                              Cheap
# For Your Eyes Only                     Cheap
# From Russia with Love              Expensive
# Golden Eye                         Expensive
# Gold Finger                        Expensive
# Licence to Kill                        Cheap
# Live and Let Die                       Cheap
# Moonraker                              Cheap
# Never Say Never Again                  Cheap
# Octopussy                              Cheap
# On Her Majesty's Secret Service        Cheap
# Quantum of Solace                  Expensive
# Skyfall                            Expensive
# Spectre                            Expensive
# The Living Daylights                   Cheap
# The Man with the Golden Gun            Cheap
# The Spy Who Loved Me               Expensive
# The World Is Not Enough                Cheap
# Thunderball                        Expensive
# Tomorrow Never Dies                    Cheap
# You Only Live Twice                Expensive
# dtype: object
